# %% [markdown]
# > **Disclaimer**
# > All notebooks in this repository were executed using Google Colab.
# > The dataset is stored in Google Drive and is not included in this repository due to privacy and storage considerations.
# > File paths may need to be updated to match your own Google Drive directory structure before running the code.

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dir_name = '/content/drive/MyDrive/THESIS/Data/'
df = pd.read_csv(f"{dir_name}Raw_Combined_Unnormalized_Data.csv")
df.head()
# Out:
#    Year  Month  Day      Date  Residential Daily Average  \
# 0  2010      1    1  1/1/2010                159360.2581
# 1  2010      1    2  1/2/2010                159360.2581
# 2  2010      1    3  1/3/2010                159360.2581
# 3  2010      1    4  1/4/2010                159360.2581
# 4  2010      1    5  1/5/2010                159360.2581
#
#    Commercial Daily Average  Government Daily Average  RAINFALL  TMAX  TMIN  \
# 0               22661.25806               5062.419355       0.0  32.8  24.1
# 1               22661.25806               5062.419355       0.0  33.6  26.1
# 2               22661.25806               5062.419355       0.0  33.1  23.5
# 3               22661.25806               5062.419355       3.4  32.4  23.8
# 4               22661.25806               5062.419355       0.0  32.2  24.9
#
#    TMEAN  WIND_SPEED  WIND_DIRECTION  RH
# 0   28.5           2             360  81
# 1   29.9           2              70  78
# ...

# %%
# Columns to normalize
columns_to_normalize = ['Residential Daily Average', 'Commercial Daily Average', 'Government Daily Average',
                        'RAINFALL', 'TMAX', 'TMIN', 'TMEAN', 'WIND_SPEED', 'WIND_DIRECTION', 'RH']

# %%
# Initialize the scaler
scaler = MinMaxScaler()

# %%
# Fit and transform the selected columns
df[columns_to_normalize] = scaler.fit_transform(df[columns_to_normalize])

# Check the result
df.head()
# Out:
#    Year  Month  Day      Date  Residential Daily Average  \
# 0  2010      1    1  1/1/2010                   0.634084
# 1  2010      1    2  1/2/2010                   0.634084
# 2  2010      1    3  1/3/2010                   0.634084
# 3  2010      1    4  1/4/2010                   0.634084
# 4  2010      1    5  1/5/2010                   0.634084
#
#    Commercial Daily Average  Government Daily Average  RAINFALL      TMAX  \
# 0                  0.051483                  0.367055  0.005770  0.996042
# 1                  0.051483                  0.367055  0.005770  0.996814
# 2                  0.051483                  0.367055  0.005770  0.996332
# 3                  0.051483                  0.367055  0.025389  0.995656
# 4                  0.051483                  0.367055  0.005770  0.995463
#
#        TMIN     TMEAN  WIND_SPEED  WIND_DIRECTION        RH
# 0  0.996203  0.996460    0.333333        1.000000  0.985401
# ...

# %%
print(combined_data.isnull().sum())
# Out:
# Year                         0
# Month                        0
# Day                          0
# Residential Daily Average    0
# Commercial Daily Average     0
# Government Daily Average     0
# RAINFALL                     0
# TMAX                         0
# TMIN                         0
# TMEAN                        0
# WIND_SPEED                   0
# WIND_DIRECTION               0
# RH                           0
# dtype: int64

# %%
# Assuming 'Date' column is already in datetime format
df['Date'] = pd.to_datetime(df['Date'])

# %%
# Plot the daily averages
plt.figure(figsize=(14, 7))

plt.plot(df['Date'], df['Residential Daily Average'], label='Residential Daily Average', alpha=0.7)
plt.plot(df['Date'], df['Commercial Daily Average'], label='Commercial Daily Average', alpha=0.7)
plt.plot(df['Date'], df['Government Daily Average'], label='Government Daily Average', alpha=0.7)

# Add title and labels
plt.title('Daily Averages Over Time')
plt.xlabel('Date')
plt.ylabel('Normalized Daily Average')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
# Define the path where you want to save the CSV file
output_path = '/content/drive/MyDrive/THESIS/Data/Normalized_Daily_Averages.csv'

# Export the DataFrame to a CSV file
df.to_csv(output_path, index=False)

print(f"Normalized data exported successfully to {output_path}")
# Out:
# Normalized data exported successfully to /content/drive/MyDrive/THESIS/Data/Normalized_Daily_Averages.csv
